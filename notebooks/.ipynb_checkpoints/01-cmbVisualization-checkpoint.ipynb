# %% [markdown]
# # imports

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import healpy as hp

# %%
path = r"/home/ryan/Documents/cosmology/cmb analysis/data/raw/COM_CMB_IQU-smica_2048_R3.00_full.fits"

# %%
cmb_map = hp.read_map(path, field = (0,1,2))
temp_map = cmb_map[0] * 1e6

hp.mollview(temp_map, title="CMB Temperature", unit="$\mu$K", min=-300, max=300)
hp.graticule()
plt.show()
