# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import healpy as hp

# %%
map_30ghz = hp.read_map(r"/home/ryan/Documents/cosmology/cmb_analysis/data/raw/LFI_SkyMap_030_1024_R3.00_full.fits", field=0) * 1e6
map_143ghz = hp.ud_grade( hp.read_map(r"/home/ryan/Documents/cosmology/cmb_analysis/data/raw/HFI_SkyMap_143_2048_R3.01_full.fits"), 
                          nside_out = 1024) * 1e6
map_353ghz = hp.ud_grade( hp.read_map(r"/home/ryan/Documents/cosmology/cmb_analysis/data/raw/HFI_SkyMap_353_2048_R3.01_full.fits"),
                           nside_out = 1024) * 1e6
map_gal_plane = hp.ud_grade( hp.read_map(r"/home/ryan/Documents/cosmology/cmb_analysis/data/raw/HFI_Mask_GalPlane-apo0_2048_R2.00.fits"),
                             nside_out = 1024) * 1e6

# %%
hp.mollview(map_30ghz, title = "30 GHz Map", min = -300, max = 300)

# %%
hp.mollview(map_143ghz, title = "143 GHz Map", min = -300, max = 300)

# %%
hp.mollview(map_353ghz, title = "353 GHz Map", min = -1e4, max = 1e4)
